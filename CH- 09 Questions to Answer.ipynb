# %% [markdown]
# # Topics to cover

# %% [markdown]
# ```
# CH-08 Python Interview Questions
# │
# ├── A. Python Fundamentals & Internals
# ├── B. Functions / Closures / Decorators
# ├── C. OOP
# ├── D. Iterators / Generators
# ├── E. Exceptions / Context Managers
# ├── F. Collections & Pythonic Code
# ├── G. Memory / Copy / Garbage Collection
# ├── H. Modules / Imports / Environments
# ├── I. Typing
# ├── J. Concurrency / Threading / Multiprocessing
# ├── K. Async Python
# ├── L. NumPy / Pandas Python Integration
# ├── M. ML / AI Engineering Python
# ├── N. Debugging / Production Scenarios
# └── O. Rapid-Fire Interview Round
# ```

# %% [markdown]
# # A. Python Fundamentasl & Internals

# %% [markdown]
# Q. What is the diff b/w variable and an object in python?
# Q. what is diff b/w `==` and `is` ?
# Q. what is integer/string `interning`??
#
# Q. Mutable vs immutable objects — what actually makes this important in Python?
#
# Q. What does "hashable" actually mean?

# %%
# Out:
# True

# %% [markdown]
# # B. Functions / Closures / Decorators

# %% [markdown]
# Q. What is the difference between a higher-order function and a first-class function?
# Q. What is LEGB?
#
# Q. What is the difference between global and nonlocal?
# Q. what is a closure?
# Q. Why would you use a closure in production?
#
# Q. What is a decorator?

# %% [markdown]
# Q. what is diff b/w `*args` and `**kwargs`?
# Q. Packing v/s unpacking
# Q.

# %% [markdown]
# # C. Object Oriented Programming.

# %% [markdown]
# Q. Diff b/w `instance`, `class` and `static methods`??
# Q. When would you use @classmethod as an alternative constructor?
# Q. what is  `super()` actually doing??
# Q. Explain MRO ??
#
# Q. Composition vs inheritance — when would you choose each?
# Q. What is polymorphism in Python?
#
# Q. ABC vs duck typing vs Protocol?
#
# Q. What is a `dataclass` and when would you use it??
#
# Q. Explain `__eq__` ..
# Q. Diff b/w `__new__` and `__init__` ??

# %% [markdown]
# # D. Iterators / Generators

# %% [markdown]
# Q. what is `iterable` ?
# Q. what is `iterator` ?
#
# Q. What is the difference between an iterable and an iterator?
#
# Q. What does `iter()` do?
# Q. What does `next()` do?
#
# Q. What actually happens inside a `for` loop??

# %% [markdown]
# Q. What is a generator?
# Q. `return` vs/ `yield` ?
#
#
# Q. How would you process a `100GB` datasest without loading everything in memory??
#
# Q. Why are generator memory efficient?

# %% [markdown]
# # E. Exception / Context Manager

# %% [markdown]
# Q. Explain `try`, `except`, `else`, `finally` ??
# Q. What is context manager?
# Q. Why does with open(...) automatically close the file?
#
# Q. What do `__enter__` and `__exit__` do ?

# %% [markdown]
# # F. Collection / Pythonic Python

# %% [markdown]
# Q. List v/s tuple - when would you chose each ?
# Q. why dictionary lookups approximately O(1) ?
#
#
# Q. How does a Python dictionary work internally?
#
# Q. what happens when two dictionary keys have the same hash?
# Q. Why must dictionary keys be hashable ?

# %% [markdown]
# Q. why use `deque` instaed of list for a queue?
# Q. `enumerate()` vss/ `range(len(..))` ??
#
#
# Q. any() / all() ?

# %% [markdown]
# # G. Memory / copy / GC

# %% [markdown]
# q. what is the diff b/w shallow and deep copy ?
# Q. Explain this
#
# ```
# a = [[1, 2], [3, 4]]
# b = a.copy()
#
# b[0].append(99)
#
# ```

# %%
a = [[1, 2], [3, 4]]
b = a.copy()

b[0].append(99)
print(b)
print(a)
# Out:
# [[1, 2, 99], [3, 4]]
# [[1, 2, 99], [3, 4]]

# %% [markdown]
# Q. why can repeated creating large python objects incraese memory usage?

# %% [markdown]
# # H. Modules / Imports / Environments

# %% [markdown]
# q. modules v/s packages.
# q. what does  `__name__ == "__main__" ` mean ?
#
#
# q. What happens when Python imports a module?
# q. Why avoid from module import *?

# %% [markdown]
# # I. Typing

# %% [markdown]
# q. Why use type hints in Python if Python is dynamically typed?
# q. list[int] vs List[int]?
# q. What does Optional[str] mean?
# q. What is TypedDict?

# %% [markdown]
# # J. Concurrency / GIL

# %% [markdown]
# q. diff b/w concurrency and parallelism ?
# q. what is GIL ?
# q. why does GIL matter ?
# q. Does the GIL mean Python cannot do parallel computation?
#
#
# q. Input/output bound task v/s CPU bound tasks
# q. Threading v/s multiprocessing
#
# q. When would you use threads?
# q. when would you use processes ??
# q. why might multiprocssing be expensive ??
#
#
# q. what is `lock`?
# q. what is `deadlock` ?
#
#
# q. what problem does `asyncio` solve?
# q. what does `async def` mean?
#
# q. async vs threading?
# q. why is async particularly useful for API servers?
# q. Why can CPU-heavy code block an async event loop?

# %% [markdown]
# # L. `AI/ML specific qns`

# %% [markdown]
# q. how would you process a dataset too large to fit into RAM?
# q. Why is composition useful in ML pipelines?
#
# q. Why can copying a large NumPy/Pandas object be expensive?
# q. What is lazy evaluation and where could it help in an ML pipeline?

# %% [markdown]
# # Production / Debugging Scenarios

# %% [markdown]
# Your API's memory usage keeps increasing after every request.
# *How would you investigate it?*

# %% [markdown]
# A Python API becomes extremely slow when 20 users hit it simultaneously.
# *What would you check first?*

# %% [markdown]
# Your model inference endpoint takes 500 ms.
# You discover 450 ms is spent waiting for an external API.
# *What Python approach could improve throughput?*

# %% [markdown]
# Two variables appear to contain the same list, but changing one changes the other.
# *How would you debug it?*

# %% [markdown]
# An async FastAPI endpoint contains a CPU-heavy Python loop.
# *Why can this hurt performance?*

# %% [markdown]
# A package works locally but fails in production.
# *What would you investigate?*
# ```
# Python version
# dependencies
# environment
# imports
# paths
# configuration
# ```

# %% [markdown]
# * Answer below??

# %%
a = [1, 2, 3]
b = a
c = a.copy()

b.append(4)
c.append(5)

print(a)
print(b)
print(c)

# %% [markdown]
# # Last mintues 10 qns:

# %% [markdown]
# -------------------
# ```
#
# Mutable vs immutable + references
# is vs ==
# Mutable default arguments
# Shallow vs deep copy
# Decorators + functools.wraps
# Generators + lazy evaluation
# Dictionary internals + hashing
# Composition vs inheritance + dependency injection
# GIL + threading vs multiprocessing
# Async vs threads vs processes
#
# ```
